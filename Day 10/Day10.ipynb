# %%
# to import the pandas Library
import pandas as pd

# %%
''' Reading the attrition Datafile'''
df=pd.read_csv("attrition.csv")

# %%
df
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
#to display the columns present
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
# to check the null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
# so there is null values in the (NumCompaniesWorked) and (TotalWorkingYears) columns

# %%
'''interpolating the null values'''
df.TotalWorkingYears=df.TotalWorkingYears.interpolate()
df.NumCompaniesWorked=df.NumCompaniesWorked.interpolate()

# %%
# So after the interpolation now there is no null values in the entire dataset as there are 4410 non-null values in every columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
#to check the duplicate values
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
#to drop the duplicate values
df.drop_duplicates()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
'''To get the information of whole Dataset'''
df.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4410.000000        4410.000000
# mean      2.063946   65029.312925            2.692517          15.209524
# ...

# %%
''' to obtain the median values'''
df.median()
# Out:
# Age                           36.0
# DistanceFromHome               7.0
# Education                      3.0
# EmployeeCount                  1.0
# EmployeeID                  2205.5
# JobLevel                       2.0
# MonthlyIncome              49190.0
# NumCompaniesWorked             2.0
# PercentSalaryHike             14.0
# StandardHours                  8.0
# StockOptionLevel               1.0
# TotalWorkingYears             10.0
# TrainingTimesLastYear          3.0
# YearsAtCompany                 5.0
# YearsSinceLastPromotion        1.0
# YearsWithCurrManager           3.0
# dtype: float64

# %%
'''To obtain the mode of dataset'''
df[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].mode()
# Out:
#    Age  DistanceFromHome  Education  MonthlyIncome  NumCompaniesWorked  \
# 0   35                 2          3          23420                 1.0
#
#    PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 11               10.0                      2
#
#    YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager
# 0               5                        0                     2

# %%
'''To obtain the variance of the dataset'''
df[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].var()
# Out:
# Age                        8.341719e+01
# DistanceFromHome           6.569144e+01
# Education                  1.048438e+00
# MonthlyIncome              2.215480e+09
# NumCompaniesWorked         6.228976e+00
# PercentSalaryHike          1.338907e+01
# TotalWorkingYears          6.051156e+01
# TrainingTimesLastYear      1.661465e+00
# YearsAtCompany             3.751728e+01
# YearsSinceLastPromotion    1.037935e+01
# YearsWithCurrManager       1.272582e+01
# dtype: float64

# %%
'''To check the skewness of the dataset'''
df[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].skew()
# Out:
# Age                        0.413005
# DistanceFromHome           0.957466
# Education                 -0.289484
# MonthlyIncome              1.368884
# NumCompaniesWorked         1.028896
# PercentSalaryHike          0.820569
# TotalWorkingYears          1.115994
# TrainingTimesLastYear      0.552748
# YearsAtCompany             1.763328
# YearsSinceLastPromotion    1.982939
# YearsWithCurrManager       0.832884
# dtype: float64

# %%
#to check the Kurtosis of the dataset
df[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].kurt()
# Out:
# Age                       -0.405951
# DistanceFromHome          -0.227045
# Education                 -0.560569
# MonthlyIncome              1.000232
# NumCompaniesWorked         0.014580
# PercentSalaryHike         -0.302638
# TotalWorkingYears          0.912654
# TrainingTimesLastYear      0.491149
# YearsAtCompany             3.923864
# YearsSinceLastPromotion    3.601761
# YearsWithCurrManager       0.167949
# dtype: float64

# %%
#importing the matplotlib library
import matplotlib.pyplot as plt

# %%
b_plot=df.Age

# %%
plt.boxplot(b_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b6921b4608>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b6921ceec8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b6921b4208>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b692244dc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b692262c48>],
#  'means': []}

# %%
'''The box plot for column Age does not contains any outliers and it is normally distributed'''
# Out:
# 'The box plot for column Age does not contains any outliers and it is normally distributed'

# %%
b_plot=df.MonthlyIncome
plt.boxplot(b_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b6924e6fc8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b6924eadc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b6924e67c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b6924eec48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b6924eed88>],
#  'means': []}

# %%
'''The box plot for column Monthly income contains outliers and it is Right skewed 
since the median line is below the normal line as for a normal distribution'''
# Out:
# 'The box plot for column Monthly income contains outliers and it is Right skewed \nsince the median line is below the normal line as for a normal distribution'

# %%
b_plot=df.YearsAtCompany
plt.boxplot(b_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b692553c88>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b692558b08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b692553ac8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b69255ef48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b692563688>],
#  'means': []}

# %%
'''The box plot for column Years at company contains many outliers and it is Right skewed 
since the median line is below the normal line as for a normal distribution'''
# Out:
# 'The box plot for column Years at company contains many outliers and it is Right skewed \nsince the median line is below the normal line as for a normal distribution'

# %%
b_plot=df.DistanceFromHome
plt.boxplot(b_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b692634c48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b692637ac8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b692634a88>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b69263cf08>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b692640648>],
#  'means': []}

# %%
'''The box plot for column Disatance from home does not contains any outliers so it is normally distributed '''
# Out:
# 'The box plot for column Disatance from home does not contains any outliers so it is normally distributed '

# %%
b_plot=df.Education
plt.boxplot(b_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b692452088>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b6924b0a08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b692380448>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b6924be348>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b692227d88>],
#  'means': []}

# %%
'''The box plot for column Education does not contains any outliers so it is normally distributed '''

# %%
df['Age'].mean()
# Out:
# 36.923809523809524

# %%
df.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4410.000000        4410.000000
# mean      2.063946   65029.312925            2.692517          15.209524
# ...

# %% [markdown]
# ___Hypothesis___

# %%
statement 1: If the age is less than 36 then there is a high atrrition rate in the company. 
statement 2: If the Years at company is less than 6 then there is a high atrrition rate in the company.
statement 3: If the Monthly Income of an employee is less than 64000 then there is a high atrrition rate in the company. 
statement 4: If the employee Distance to home is less than 10 then there is a high atrrition rate in the company.
statement 5: If the Education is less than 3 i.e Below Bachelor then there is a high atrrition rate in the company. 
statement 6: If the Education Field of an employee is not from a Technical Degree then there is a high atrrition rate in the company.
statement 7: If the Education Field of an employee is Marketing then there is a high atrrition rate in the company.
statement 8: If the Education Field of an employee is from others then there is a low atrrition rate in the company.
statement 9: If the Job Level of an employee is less than 2 then there is a high atrrition rate in the company.
statement 10: If the Percentage Hike of an employee is less than 14 then there is a high atrrition rate in the company.

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df["EducationField"].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)
